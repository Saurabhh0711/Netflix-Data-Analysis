# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
data = pd.read_csv('train.csv')
data
# Out:
#       Unnamed: 0 show_id     type  \
# 0           6128   s6129  TV Show
# 1           7018   s7019  TV Show
# 2           4657   s4658  TV Show
# 3           6167   s6168    Movie
# 4           3562   s3563    Movie
# ...          ...     ...      ...
# 6218         346    s347    Movie
# 6219        5766   s5767    Movie
# 6220        6131   s6132    Movie
# 6221         124    s125    Movie
# 6222        3061   s3062  TV Show
#
#                                                   title          director  \
# 0                       The Big Family Cooking Showdown               NaN
# 1                  The World's Most Extraordinary Homes               NaN
# 2                                         One-Punch Man               NaN
# 3                        The Boy Who Harnessed the Wind  Chiwetel Ejiofor
# 4                      LeapFrog: Sing-along, Read-along        Ron Myrick
# ...                                                 ...               ...
# 6218                                      Ahista Ahista       Shivam Nair
# 6219                 Spookley and the Christmas Kittens       Bernie Denk
# 6220  The Bill Murray Stories: Life Lessons Learned ...    Tommy Avallone
# 6221                                              5Gang        Matei Dima
# 6222  Is It Wrong to Try to Pick Up Girls in a Dungeon?               NaN
#
#                                                    cast         country  \
# 0     Zoe Ball, Nadiya Hussain, Giorgio Locatelli, R...  United Kingdom
# 1                        Piers Taylor, Caroline Quentin  United Kingdom
# 2     Makoto Furukawa, Kaito Ishikawa, Yuki Kaji, Ao...           Japan
# 3     Maxwell Simba, Chiwetel Ejiofor, Aïssa Maïga, ...  United Kingdom
# 4                       Julie Maddalena, Cindy Robinson             NaN
# ...                                                 ...             ...
# 6218  Abhay Deol, Soha Ali Khan, Shayan Munshi, Kami...           India
# 6219  Vlasta Vrana, Sonja Ball, Craig Francis, Richa...   United States
# 6220  Tommy Avallone, Bill Murray, Joel Murray, Pete...   United States
# 6221  Andrei Selaru, Dorian Popa, Julia Marcan, Ana ...         Romania
# 6222  Yoshitsugu Matsuoka, Inori Minase, Saori Onish...           Japan
#
#              date_added  release_year  duration  \
# 0     February 22, 2019          2018         2
# 1      January 18, 2019          2019         3
# 2        March 20, 2017          2015         1
# 3         March 1, 2019          2019       114
# 4        April 15, 2020          2011        32
# ...                 ...           ...       ...
# 6218  December 31, 2019          2006       122
# 6219  November 30, 2020          2019        45
# 6220  December 31, 2018          2018        72
# 6221     April 27, 2020          2019        96
# 6222   February 1, 2020          2015         1
#
#                                             description          genre
# 0     In this unscripted series, families passionate...     British TV
# 1     Award-winning architect Piers Taylor and actre...     British TV
# 2     The most powerful superhero in the world can k...   Anime Series
# 3     Inspired by a science book, 13-year-old Willia...       Children
# 4     Using rhythm and rhymes, a funky band and a co...       Children
# ...                                                 ...            ...
# 6218  Stood up by her groom at the altar, a young wo...         Dramas
# 6219  When a green cat and three stray kittens wind ...       Children
# 6220  This documentary highlights spontaneous encoun...  Documentaries
# 6221  To keep the band together, Selly tries to earn...       Comedies
# 6222  Lovable goof Bell Cranel wants an adventure, a...   Anime Series
#
# [6223 rows x 12 columns]

# %%
df1 = data.drop(['date_added','release_year','duration','show_id','Unnamed: 0'], axis=1)

# %%
df1
# Out:
#          type                                              title  \
# 0     TV Show                    The Big Family Cooking Showdown
# 1     TV Show               The World's Most Extraordinary Homes
# 2     TV Show                                      One-Punch Man
# 3       Movie                     The Boy Who Harnessed the Wind
# 4       Movie                   LeapFrog: Sing-along, Read-along
# ...       ...                                                ...
# 6218    Movie                                      Ahista Ahista
# 6219    Movie                 Spookley and the Christmas Kittens
# 6220    Movie  The Bill Murray Stories: Life Lessons Learned ...
# 6221    Movie                                              5Gang
# 6222  TV Show  Is It Wrong to Try to Pick Up Girls in a Dungeon?
#
#               director                                               cast  \
# 0                  NaN  Zoe Ball, Nadiya Hussain, Giorgio Locatelli, R...
# 1                  NaN                     Piers Taylor, Caroline Quentin
# 2                  NaN  Makoto Furukawa, Kaito Ishikawa, Yuki Kaji, Ao...
# 3     Chiwetel Ejiofor  Maxwell Simba, Chiwetel Ejiofor, Aïssa Maïga, ...
# 4           Ron Myrick                    Julie Maddalena, Cindy Robinson
# ...                ...                                                ...
# 6218       Shivam Nair  Abhay Deol, Soha Ali Khan, Shayan Munshi, Kami...
# 6219       Bernie Denk  Vlasta Vrana, Sonja Ball, Craig Francis, Richa...
# 6220    Tommy Avallone  Tommy Avallone, Bill Murray, Joel Murray, Pete...
# 6221        Matei Dima  Andrei Selaru, Dorian Popa, Julia Marcan, Ana ...
# 6222               NaN  Yoshitsugu Matsuoka, Inori Minase, Saori Onish...
#
#              country                                        description  \
# 0     United Kingdom  In this unscripted series, families passionate...
# 1     United Kingdom  Award-winning architect Piers Taylor and actre...
# 2              Japan  The most powerful superhero in the world can k...
# 3     United Kingdom  Inspired by a science book, 13-year-old Willia...
# 4                NaN  Using rhythm and rhymes, a funky band and a co...
# ...              ...                                                ...
# 6218           India  Stood up by her groom at the altar, a young wo...
# 6219   United States  When a green cat and three stray kittens wind ...
# 6220   United States  This documentary highlights spontaneous encoun...
# 6221         Romania  To keep the band together, Selly tries to earn...
# 6222           Japan  Lovable goof Bell Cranel wants an adventure, a...
#
#               genre
# 0        British TV
# 1        British TV
# 2      Anime Series
# 3          Children
# 4          Children
# ...             ...
# 6218         Dramas
# 6219       Children
# 6220  Documentaries
# 6221       Comedies
# 6222   Anime Series
#
# [6223 rows x 7 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6223 entries, 0 to 6222
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   type         6223 non-null   object
#  1   title        6223 non-null   object
#  2   director     4330 non-null   object
#  3   cast         5654 non-null   object
#  4   country      5800 non-null   object
#  5   description  6223 non-null   object
#  6   genre        6223 non-null   object
# dtypes: object(7)
# memory usage: 340.4+ KB

# %%
df1.isnull().sum()
# Out:
# type              0
# title             0
# director       1893
# cast            569
# country         423
# description       0
# genre             0
# dtype: int64

# %%
df1.dropna(inplace=True)

# %%
df1.isnull().sum()
# Out:
# type           0
# title          0
# director       0
# cast           0
# country        0
# description    0
# genre          0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1
# Out:
#        type                                              title  \
# 3     Movie                     The Boy Who Harnessed the Wind
# 5     Movie                          Mutiny of the Worker Bees
# 6     Movie                                        John Carter
# 7     Movie                                       Kung Fu Yoga
# 9     Movie                                          Lady Bird
# ...     ...                                                ...
# 6217  Movie                                          The Titan
# 6218  Movie                                      Ahista Ahista
# 6219  Movie                 Spookley and the Christmas Kittens
# 6220  Movie  The Bill Murray Stories: Life Lessons Learned ...
# 6221  Movie                                              5Gang
#
#               director                                               cast  \
# 3     Chiwetel Ejiofor  Maxwell Simba, Chiwetel Ejiofor, Aïssa Maïga, ...
# 5        Carlos Morett  Gustavo Egelhaaf, Alejandro Suárez, Bárbara de...
# 6       Andrew Stanton  Taylor Kitsch, Lynn Collins, Samantha Morton, ...
# 7         Stanley Tong  Jackie Chan, Disha Patani, Amyra Dastur, Sonu ...
# 9         Greta Gerwig  Saoirse Ronan, Laurie Metcalf, Tracy Letts, Lu...
# ...                ...                                                ...
# 6217      Lennart Ruff  Sam Worthington, Taylor Schilling, Agyness Dey...
# 6218       Shivam Nair  Abhay Deol, Soha Ali Khan, Shayan Munshi, Kami...
# 6219       Bernie Denk  Vlasta Vrana, Sonja Ball, Craig Francis, Richa...
# 6220    Tommy Avallone  Tommy Avallone, Bill Murray, Joel Murray, Pete...
# 6221        Matei Dima  Andrei Selaru, Dorian Popa, Julia Marcan, Ana ...
#
#              country                                        description  \
# 3     United Kingdom  Inspired by a science book, 13-year-old Willia...
# 5             Mexico  When Omar's grandfather forces him to get a jo...
# 6      United States  One minute, Civil War veteran John Carter is e...
# 7              China  Two mismatched archaeologists battle a team of...
# 9      United States  An intrepid high schooler in Sacramento underg...
# ...              ...                                                ...
# 6217  United Kingdom  On a bleak future Earth, a soldier endures a r...
# 6218           India  Stood up by her groom at the altar, a young wo...
# 6219   United States  When a green cat and three stray kittens wind ...
# 6220   United States  This documentary highlights spontaneous encoun...
# 6221         Romania  To keep the band together, Selly tries to earn...
#
#               genre
# 3          Children
# 5          Comedies
# 6            Action
# 7            Action
# 9          Comedies
# ...             ...
# 6217         Dramas
# 6218         Dramas
# 6219       Children
# 6220  Documentaries
# 6221       Comedies
#
# [3855 rows x 7 columns]

# %%
df1['tags'] = df1[''] + ' ' + df1['keywords'] + df1['genres'] + df1['cast'] + df1['crew']
