# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
data = pd.read_csv('train.csv')
data
# Out:
#       Unnamed: 0 show_id     type  \
# 0           6128   s6129  TV Show
# 1           7018   s7019  TV Show
# 2           4657   s4658  TV Show
# 3           6167   s6168    Movie
# 4           3562   s3563    Movie
# ...          ...     ...      ...
# 6218         346    s347    Movie
# 6219        5766   s5767    Movie
# 6220        6131   s6132    Movie
# 6221         124    s125    Movie
# 6222        3061   s3062  TV Show
#
#                                                   title          director  \
# 0                       The Big Family Cooking Showdown               NaN
# 1                  The World's Most Extraordinary Homes               NaN
# 2                                         One-Punch Man               NaN
# 3                        The Boy Who Harnessed the Wind  Chiwetel Ejiofor
# 4                      LeapFrog: Sing-along, Read-along        Ron Myrick
# ...                                                 ...               ...
# ...

# %%
df1 = data.drop(['date_added','release_year','duration','show_id','Unnamed: 0'], axis=1)

# %%
df1
# Out:
#          type                                              title  \
# 0     TV Show                    The Big Family Cooking Showdown
# 1     TV Show               The World's Most Extraordinary Homes
# 2     TV Show                                      One-Punch Man
# 3       Movie                     The Boy Who Harnessed the Wind
# 4       Movie                   LeapFrog: Sing-along, Read-along
# ...       ...                                                ...
# 6218    Movie                                      Ahista Ahista
# 6219    Movie                 Spookley and the Christmas Kittens
# 6220    Movie  The Bill Murray Stories: Life Lessons Learned ...
# 6221    Movie                                              5Gang
# 6222  TV Show  Is It Wrong to Try to Pick Up Girls in a Dungeon?
#
#               director                                               cast  \
# 0                  NaN  Zoe Ball, Nadiya Hussain, Giorgio Locatelli, R...
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6223 entries, 0 to 6222
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   type         6223 non-null   object
#  1   title        6223 non-null   object
#  2   director     4330 non-null   object
#  3   cast         5654 non-null   object
#  4   country      5800 non-null   object
#  5   description  6223 non-null   object
#  6   genre        6223 non-null   object
# dtypes: object(7)
# memory usage: 340.4+ KB

# %%
df1.isnull().sum()
# Out:
# type              0
# title             0
# director       1893
# cast            569
# country         423
# description       0
# genre             0
# dtype: int64

# %%
df1.dropna(inplace=True)

# %%
df1.isnull().sum()
# Out:
# type           0
# title          0
# director       0
# cast           0
# country        0
# description    0
# genre          0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1
# Out:
#        type                                              title  \
# 3     Movie                     The Boy Who Harnessed the Wind
# 5     Movie                          Mutiny of the Worker Bees
# 6     Movie                                        John Carter
# 7     Movie                                       Kung Fu Yoga
# 9     Movie                                          Lady Bird
# ...     ...                                                ...
# 6217  Movie                                          The Titan
# 6218  Movie                                      Ahista Ahista
# 6219  Movie                 Spookley and the Christmas Kittens
# 6220  Movie  The Bill Murray Stories: Life Lessons Learned ...
# 6221  Movie                                              5Gang
#
#               director                                               cast  \
# 3     Chiwetel Ejiofor  Maxwell Simba, Chiwetel Ejiofor, Aïssa Maïga, ...
# ...

# %%
df1=df1.drop(['country'], axis=1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3855 entries, 3 to 6221
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   type         3855 non-null   object
#  1   title        3855 non-null   object
#  2   director     3855 non-null   object
#  3   cast         3855 non-null   object
#  4   description  3855 non-null   object
#  5   genre        3855 non-null   object
# dtypes: object(6)
# memory usage: 210.8+ KB

# %%
df1.head(6)
# Out:
#      type                           title          director  \
# 3   Movie  The Boy Who Harnessed the Wind  Chiwetel Ejiofor
# 5   Movie       Mutiny of the Worker Bees     Carlos Morett
# 6   Movie                     John Carter    Andrew Stanton
# 7   Movie                    Kung Fu Yoga      Stanley Tong
# 9   Movie                       Lady Bird      Greta Gerwig
# 10  Movie                    Main Hoon Na        Farah Khan
#
#                                                  cast  \
# 3   Maxwell Simba, Chiwetel Ejiofor, Aïssa Maïga, ...
# 5   Gustavo Egelhaaf, Alejandro Suárez, Bárbara de...
# 6   Taylor Kitsch, Lynn Collins, Samantha Morton, ...
# 7   Jackie Chan, Disha Patani, Amyra Dastur, Sonu ...
# 9   Saoirse Ronan, Laurie Metcalf, Tracy Letts, Lu...
# 10  Shah Rukh Khan, Sunil Shetty, Sushmita Sen, Za...
#
#                                           description     genre
# 3   Inspired by a science book, 13-year-old Willia...  Children
# ...

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1.head()['genre']
# Out:
# 3    Children
# 5    Comedies
# 6      Action
# 7      Action
# 9    Comedies
# Name: genre, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer


tfv = TfidfVectorizer(min_df=3,
                      max_features=None, 
                      
                      # this removes the all the characters from the sentences
                      strip_accents = 'unicode',
                      analyzer = 'word',
                      token_pattern = r'\w{1,}',
                      
                      ngram_range = (1, 3), # takes combination 1-3 words
                      stop_words = 'english') # this will remove all the unnecessary words like the that etc.

# Filling NaNs with empty string
df1['genre'] = df1['genre'].fillna('')

# %%
tfv_matrix = tfv.fit_transform(df1['genre'])

# %%
tfv_matrix.shape
# Out:
# (3855, 38)

# %%
from sklearn.metrics.pairwise import sigmoid_kernel

# Compute the sigmoid kernel which brings the values between 0 and 1
sig = sigmoid_kernel(tfv_matrix, tfv_matrix)

# %%
sig[0]
# Out:
# array([0.77242651, 0.76159416, 0.76159416, ..., 0.77242651, 0.76159416,
#        0.76159416])

# %%
indices = pd.Series(df1.index, index = df1['title'])

# %%
indices
# Out:
# title
# The Boy Who Harnessed the Wind                                          3
# Mutiny of the Worker Bees                                               5
# John Carter                                                             6
# Kung Fu Yoga                                                            7
# Lady Bird                                                               9
#                                                                      ...
# The Titan                                                            6217
# Ahista Ahista                                                        6218
# Spookley and the Christmas Kittens                                   6219
# The Bill Murray Stories: Life Lessons Learned From a Mythical Man    6220
# 5Gang                                                                6221
# Length: 3855, dtype: int64

# %%
indices['The Boy Who Harnessed the Wind']
# Out:
# 3

# %%
def give_rec(title,sig=sig):
    # Get the index corresponding to original_title
    idx = indices[title]

    # Get the pairwsie similarity scores 
    sig_scores = list(enumerate(sig[idx]))

    # Sort the movies 
    sig_scores = sorted(sig_scores, key=lambda x: x[1], reverse=True)

    # Scores of the 10 most similar movies
    sig_scores = sig_scores[1:11]

    # Movie indices
    movie_indices = [i[0] for i in sig_scores]

    # Top 10 most similar movies
    return df1['title'].iloc[movie_indices]

# %%
give_rec('The Dukes of Hazzard')
# Out:
# 30                Shepherds and Butchers
# 46                           Gran Torino
# 47                          Khido Khundi
# 51                        Mehandi Circus
# 58                           Jersey Boys
# 63    The Dark Side of Life: Mumbai City
# 69                                  Solo
# 82                          The Emigrant
# 92                         Sigaram Thodu
# 98                                Desire
# Name: title, dtype: object

# %%
df1.loc[df1.title == 'The Boy Who Harnessed the Wind']
# Out:
#     type                           title          director  \
# 3  Movie  The Boy Who Harnessed the Wind  Chiwetel Ejiofor
#
#                                                 cast  \
# 3  Maxwell Simba, Chiwetel Ejiofor, Aïssa Maïga, ...
#
#                                          description     genre
# 3  Inspired by a science book, 13-year-old Willia...  Children

# %%
df1.loc[df1.title == 'The Dark Side of Life: Mumbai City']
# Out:
#      type                               title    director  \
# 63  Movie  The Dark Side of Life: Mumbai City  Tariq Khan
#
#                                                  cast  \
# 63  Mahesh Bhatt, Kay Kay Menon, Avii, Nikhil Ratn...
#
#                                           description   genre
# 63  Struggling with Mumbai's pressures and private...  Dramas
